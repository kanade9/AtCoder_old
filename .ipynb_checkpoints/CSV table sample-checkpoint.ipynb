# %%
import pandas as pd
pd.read_csv("population.csv", encoding="SHIFT_JIS")
# Out:
#     都道府県  平成12年  平成17年  平成22年  平成27年  平成28年
# 0    東京都  12064  12577  13159  13515  13624
# 1   神奈川県   8490   8792   9048   9126   9145
# 2    大阪府   8805   8817   8865   8839   8833
# 3    愛知県   7043   7255   7411   7483   7507
# 4    埼玉県   6938   7054   7195   7267   7289
# 5    千葉県   5926   6056   6216   6223   6236
# 6    兵庫県   5551   5591   5588   5535   5520
# 7    北海道   5683   5628   5506   5382   5352
# 8    福岡県   5016   5050   5072   5102   5104
# 9    静岡県   3767   3792   3765   3700   3688
# 10   茨城県   2986   2975   2970   2917   2905
# 11   広島県   2879   2877   2861   2844   2837
# 12   京都府   2644   2648   2636   2610   2605
# 13   宮城県   2365   2360   2348   2334   2330
# 14   新潟県   2476   2431   2374   2304   2286
# 15   長野県   2215   2196   2152   2099   2088
# 16   岐阜県   2108   2107   2081   2032   2022
# 17   群馬県   2025   2024   2008   1973   1967
# 18   栃木県   2005   2017   2008   1974   1966
# 19   岡山県   1951   1957   1945   1922   1915
# 20   福島県   2127   2091   2029   1914   1901
# 21   三重県   1857   1867   1855   1816   1808
# 22   熊本県   1859   1842   1817   1786   1774
# 23  鹿児島県   1786   1753   1706   1648   1637
# 24   沖縄県   1318   1362   1393   1434   1439
# 25   滋賀県   1343   1380   1411   1413   1413
# 26   山口県   1528   1493   1451   1405   1394
# 27   愛媛県   1493   1468   1431   1385   1375
# 28   長崎県   1517   1479   1427   1377   1367
# 29   奈良県   1443   1421   1401   1364   1356
# 30   青森県   1476   1437   1373   1308   1293
# 31   岩手県   1416   1385   1330   1280   1268
# 32   大分県   1221   1210   1197   1166   1160
# 33   石川県   1181   1174   1170   1154   1151
# 34   山形県   1244   1216   1169   1124   1113
# 35   宮崎県   1170   1153   1135   1104   1096
# 36   富山県   1121   1112   1093   1066   1061
# 37   秋田県   1189   1146   1086   1023   1010
# 38   香川県   1023   1012    996    976    972
# 39  和歌山県   1070   1036   1002    964    954
# 40   山梨県    888    885    863    835    830
# 41   佐賀県    877    866    850    833    828
# 42   福井県    829    822    806    787    782
# 43   徳島県    824    810    785    756    750
# 44   高知県    814    796    764    728    721
# 45   島根県    762    742    717    694    690
# 46   鳥取県    613    607    589    573    570

# %%
import pandas as pd
df=pd.read_csv()population.csv",encoding="SHIFT_JIS")
df.sort_values(by=["平成28年"],ascending=True)
# Out:
#   File "<ipython-input-2-7f1770dd5df0>", line 2
#     df=pd.read_csv()population.csv",encoding="SHIFT_JIS")
#                              ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df=pd.read_csv(population.csv",encoding="SHIFT_JIS")
df.sort_values(by=["平成28年"],ascending=True)
# Out:
#   File "<ipython-input-3-8690e4dec856>", line 2
#     df=pd.read_csv(population.csv",encoding="SHIFT_JIS")
#                                             ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df=pd.read_csv("population.csv",encoding="SHIFT_JIS")
df.sort_values(by=["平成28年"],ascending=True)
# Out:
#     都道府県  平成12年  平成17年  平成22年  平成27年  平成28年
# 46   鳥取県    613    607    589    573    570
# 45   島根県    762    742    717    694    690
# 44   高知県    814    796    764    728    721
# 43   徳島県    824    810    785    756    750
# 42   福井県    829    822    806    787    782
# 41   佐賀県    877    866    850    833    828
# 40   山梨県    888    885    863    835    830
# 39  和歌山県   1070   1036   1002    964    954
# 38   香川県   1023   1012    996    976    972
# 37   秋田県   1189   1146   1086   1023   1010
# 36   富山県   1121   1112   1093   1066   1061
# 35   宮崎県   1170   1153   1135   1104   1096
# 34   山形県   1244   1216   1169   1124   1113
# 33   石川県   1181   1174   1170   1154   1151
# 32   大分県   1221   1210   1197   1166   1160
# 31   岩手県   1416   1385   1330   1280   1268
# 30   青森県   1476   1437   1373   1308   1293
# 29   奈良県   1443   1421   1401   1364   1356
# 28   長崎県   1517   1479   1427   1377   1367
# 27   愛媛県   1493   1468   1431   1385   1375
# 26   山口県   1528   1493   1451   1405   1394
# 25   滋賀県   1343   1380   1411   1413   1413
# 24   沖縄県   1318   1362   1393   1434   1439
# 23  鹿児島県   1786   1753   1706   1648   1637
# 22   熊本県   1859   1842   1817   1786   1774
# 21   三重県   1857   1867   1855   1816   1808
# 20   福島県   2127   2091   2029   1914   1901
# 19   岡山県   1951   1957   1945   1922   1915
# 18   栃木県   2005   2017   2008   1974   1966
# 17   群馬県   2025   2024   2008   1973   1967
# 16   岐阜県   2108   2107   2081   2032   2022
# 15   長野県   2215   2196   2152   2099   2088
# 14   新潟県   2476   2431   2374   2304   2286
# 13   宮城県   2365   2360   2348   2334   2330
# 12   京都府   2644   2648   2636   2610   2605
# 11   広島県   2879   2877   2861   2844   2837
# 10   茨城県   2986   2975   2970   2917   2905
# 9    静岡県   3767   3792   3765   3700   3688
# 8    福岡県   5016   5050   5072   5102   5104
# 7    北海道   5683   5628   5506   5382   5352
# 6    兵庫県   5551   5591   5588   5535   5520
# 5    千葉県   5926   6056   6216   6223   6236
# 4    埼玉県   6938   7054   7195   7267   7289
# 3    愛知県   7043   7255   7411   7483   7507
# 2    大阪府   8805   8817   8865   8839   8833
# 1   神奈川県   8490   8792   9048   9126   9145
# 0    東京都  12064  12577  13159  13515  13624

# %%
import pandas as pd
df=pd.read_csv(population.csv",encoding="SHIFT_JIS")
df.sort_values(by=["平成28年"],ascending=false)
# Out:
#   File "<ipython-input-5-343fe20b04a0>", line 2
#     df=pd.read_csv(population.csv",encoding="SHIFT_JIS")
#                                             ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df="pd.read_csv(population.csv",encoding="SHIFT_JIS")
df.sort_values(by=["平成28年"],ascending=false)
# Out:
#   File "<ipython-input-6-a47efb578295>", line 2
#     df="pd.read_csv(population.csv",encoding="SHIFT_JIS")
#                                                         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df=pd.read_csv("population.csv",encoding="SHIFT_JIS")
df.sort_values(by=["平成28年"],ascending=false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-983a94764528> in <module>
#       1 import pandas as pd
#       2 df=pd.read_csv("population.csv",encoding="SHIFT_JIS")
# ----> 3 df.sort_values(by=["平成28年"],ascending=false)
#
# NameError: name 'false' is not defined

# %%
# %matplotlib inline
import panda as pd
df=pd.read_csv("population.csv",encoding="SHIFT_JIS")
df.plot.bar(y=['平成28年'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-2c4c223b8192> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 import panda as pd
#       3 df=pd.read_csv("population.csv",encoding="SHIFT_JIS")
#       4 df.plot.bar(y=['平成28年'])
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd
df=pd.read_csv("population.csv",encoding="SHIFT_JIS")
df.sort_values(by=["平成28年"],ascending=False)
# Out:
#     都道府県  平成12年  平成17年  平成22年  平成27年  平成28年
# 0    東京都  12064  12577  13159  13515  13624
# 1   神奈川県   8490   8792   9048   9126   9145
# 2    大阪府   8805   8817   8865   8839   8833
# 3    愛知県   7043   7255   7411   7483   7507
# 4    埼玉県   6938   7054   7195   7267   7289
# 5    千葉県   5926   6056   6216   6223   6236
# 6    兵庫県   5551   5591   5588   5535   5520
# 7    北海道   5683   5628   5506   5382   5352
# 8    福岡県   5016   5050   5072   5102   5104
# 9    静岡県   3767   3792   3765   3700   3688
# 10   茨城県   2986   2975   2970   2917   2905
# 11   広島県   2879   2877   2861   2844   2837
# 12   京都府   2644   2648   2636   2610   2605
# 13   宮城県   2365   2360   2348   2334   2330
# 14   新潟県   2476   2431   2374   2304   2286
# 15   長野県   2215   2196   2152   2099   2088
# 16   岐阜県   2108   2107   2081   2032   2022
# 17   群馬県   2025   2024   2008   1973   1967
# 18   栃木県   2005   2017   2008   1974   1966
# 19   岡山県   1951   1957   1945   1922   1915
# 20   福島県   2127   2091   2029   1914   1901
# 21   三重県   1857   1867   1855   1816   1808
# 22   熊本県   1859   1842   1817   1786   1774
# 23  鹿児島県   1786   1753   1706   1648   1637
# 24   沖縄県   1318   1362   1393   1434   1439
# 25   滋賀県   1343   1380   1411   1413   1413
# 26   山口県   1528   1493   1451   1405   1394
# 27   愛媛県   1493   1468   1431   1385   1375
# 28   長崎県   1517   1479   1427   1377   1367
# 29   奈良県   1443   1421   1401   1364   1356
# 30   青森県   1476   1437   1373   1308   1293
# 31   岩手県   1416   1385   1330   1280   1268
# 32   大分県   1221   1210   1197   1166   1160
# 33   石川県   1181   1174   1170   1154   1151
# 34   山形県   1244   1216   1169   1124   1113
# 35   宮崎県   1170   1153   1135   1104   1096
# 36   富山県   1121   1112   1093   1066   1061
# 37   秋田県   1189   1146   1086   1023   1010
# 38   香川県   1023   1012    996    976    972
# 39  和歌山県   1070   1036   1002    964    954
# 40   山梨県    888    885    863    835    830
# 41   佐賀県    877    866    850    833    828
# 42   福井県    829    822    806    787    782
# 43   徳島県    824    810    785    756    750
# 44   高知県    814    796    764    728    721
# 45   島根県    762    742    717    694    690
# 46   鳥取県    613    607    589    573    570

# %%
# %matplotlib inline
import pandas as pd
df=pd.read_csv("population.csv",encoding="SHIFT_JIS")
df.plot.bar(y=["平成28年"])

# %%
# %matplotlib inline
import pandas as pd
df=pd.read_csv("population.csv",encoding="SHIFT_JIS")
df.plot.bar(y=['平成28年'])

# %%
# %matplotlib inline
import pandas as pd
df=pd.read_csv("population.csv",encoding="SHIFT_JIS")
df.plot.bar(y=['平成28年','平成12年'])

# %%
import matplotlib as mpl
mpl._path_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-39881dbd6b93> in <module>
#       1 import matplotlib as mpl
# ----> 2 mpl._path_
#
# AttributeError: module 'matplotlib' has no attribute '_path_'

# %%
import matplotlib as mpl
mpl. _path_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-226d1c8bf9ea> in <module>
#       1 import matplotlib as mpl
# ----> 2 mpl. _path_
#
# AttributeError: module 'matplotlib' has no attribute '_path_'

# %%
import matplotlib as abc
abc._path_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-1a2bcd95935a> in <module>
#       1 import matplotlib as abc
# ----> 2 abc._path_
#
# AttributeError: module 'matplotlib' has no attribute '_path_'

# %%
import matplotlib as abc
abc.＿path＿
# Out:
#   File "<ipython-input-18-b8e1be3381d2>", line 2
#     abc.＿path＿
#              ^
# SyntaxError: invalid character in identifier

# %%
font.family:IPAexGothic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-765457e45a3d> in <module>
# ----> 1 font.family:IPAexGothic
#
# NameError: name 'font' is not defined

# %%
font.family:IPAexGothic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-765457e45a3d> in <module>
# ----> 1 font.family:IPAexGothic
#
# NameError: name 'font' is not defined

# %%
font.family:IPAexGothic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-765457e45a3d> in <module>
# ----> 1 font.family:IPAexGothic
#
# NameError: name 'font' is not defined

# %%
font.family : IPAexGothic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-22c8d560d005> in <module>
# ----> 1 font.family : IPAexGothic
#
# NameError: name 'font' is not defined

# %%
import matplotlib as mpl
 mpl.__path__
# Out:
#   File "<ipython-input-23-62cb9b8ab445>", line 2
#     mpl.__path__
#     ^
# IndentationError: unexpected indent

# %%
import matplotlib as mpl
mpl.__path__
# Out:
# ['c:\\users\\kazuya\\miniconda3\\lib\\site-packages\\matplotlib']

# %%
import os, os.path
 path = os.path.expanduser('~') + "/.matplotlib"
 if not os.path.exists(path): os.mkdir(path)
 with open(path + "/matplotlibrc", "w") as f:
  f.write("font.family : IPAexGothic\n")
 print("ok")
# Out:
#   File "<ipython-input-27-b9c9ec0b7c3b>", line 2
#     path = os.path.expanduser('~') + "/.matplotlib"
#     ^
# IndentationError: unexpected indent

# %%
import os, os.path
path = os.path.expanduser('~') + "/.matplotlib"
if not os.path.exists(path): os.mkdir(path)
with open(path + "/matplotlibrc", "w") as f:
 f.write("font.family : IPAexGothic\n")
print("ok")
# Out:
# ok

# %%
# %matplotlib inline
import pandas as pd
df=pd.read_csv("population.csv",encoding="SHIFT_JIS")
df.plot.bar(y=['平成28年','平成12年'])
